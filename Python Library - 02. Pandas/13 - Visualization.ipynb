# %%
import pandas as pd 
data = pd.read_csv("Automobile_data.csv")
data = data.head()

# %%
data['length'].plot(kind='line', figsize=(10, 5), color='red')
# Out:
# <AxesSubplot:>

# %%
data['length'].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
data['length'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['length'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data['length'].plot(kind='pie', figsize=(10,5), colormap='Pastel1')
# Out:
# <AxesSubplot:ylabel='length'>

# %%
data['length'].plot(kind='line')
# Out:
# <AxesSubplot:>
