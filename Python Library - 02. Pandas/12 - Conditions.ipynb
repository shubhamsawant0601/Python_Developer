# %%
import pandas as pd
data = pd.read_csv("nba.csv")
data.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %% [markdown]
# # Conditional Filtering

# %%
# conditional 
filter1 = data["Number"]>5
filter2 = data["Number"]<50
filter3 = data["Age"]>20
filter4 = data["Age"]<30
filter5 = data["Weight"].isnull()==False

data.where(filter1 & filter2 & filter3 & filter4)
# Out:
#                  Name                Team  Number Position   Age Height  \
# 370               NaN                 NaN     NaN      NaN   NaN    NaN
# 376               NaN                 NaN     NaN      NaN   NaN    NaN
# 368               NaN                 NaN     NaN      NaN   NaN    NaN
# 369               NaN                 NaN     NaN      NaN   NaN    NaN
# 371      Jarell Eddie  Washington Wizards     8.0       SG  24.0    6-7
# ..                ...                 ...     ...      ...   ...    ...
# 310  Tim Hardaway Jr.       Atlanta Hawks    10.0       SG  24.0    6-6
# 309     Kent Bazemore       Atlanta Hawks    24.0       SF  26.0    6-5
# 315               NaN                 NaN     NaN      NaN   NaN    NaN
# 317   Lamar Patterson       Atlanta Hawks    13.0       SG  24.0    6-5
# 457               NaN                 NaN     NaN      NaN   NaN    NaN
#
#      Weight        College     Salary
# 370     NaN            NaN        NaN
# ...

# %%
# Data filtering with where method
data['Indexes'] = data["Name"].str.find('J')==0
data  = data.where(data['Indexes']==True)
data.dropna()
# Out:
#                 Name                Team  Number Position   Age Height  \
# 370     Jared Dudley  Washington Wizards     1.0       SF  30.0    6-7
# 371     Jarell Eddie  Washington Wizards     8.0       SG  24.0    6-7
# 374       JJ Hickson  Washington Wizards    21.0        C  27.0    6-9
# 382        John Wall  Washington Wizards     2.0       PG  25.0    6-4
# 456      Jeff Withey           Utah Jazz    24.0        C  26.0    7-0
# ..               ...                 ...     ...      ...   ...    ...
# 13       James Young      Boston Celtics    13.0       SG  20.0    6-6
# 10   Jared Sullinger      Boston Celtics     7.0        C  24.0    6-9
# 1        Jae Crowder      Boston Celtics    99.0       SF  25.0    6-6
# 6      Jordan Mickey      Boston Celtics    55.0       PF  21.0    6-8
# 323      Jeff Teague       Atlanta Hawks     0.0       PG  27.0    6-2
#
#      Weight               College      Salary  Indexes
# 370   225.0        Boston College   4375000.0     True
# ...
