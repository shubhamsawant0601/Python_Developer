# %% [markdown]
# # Python Packages
# ## Package
#
# A package is a collection of modules. In other words, it is a directory of Python modules.
#
# ### The packages discussed in this course are:
#
# 1. Built-in
# 2. Regular Expression
# 3. Third-party
# 4. Serialization and De-serialization
#
#
# ### 1. Built-in packages are:
#
# 1. os
# 2. sys
# 3. shutils
# 4. datetime
# 5. collections
# 6. itertools

# %% [markdown]
# # 1. OS

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import os

os.name()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-2e562168c3e2> in <module>
#       1 import os
#       2
# ----> 3 os.name()
#
# TypeError: 'str' object is not callable

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Shubham\\Documents\\Python Developer'

# %%
os.mkdir("new folder from python tutorial")

# %%
os.rename("Coding", "Coding_new")

# %%
os.rename("Coding_new", "Coding")

# %%
os.rmdir('new folder from python tutorial')

# %%
os.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-41541597342e> in <module>
# ----> 1 os.close()
#
# TypeError: close() missing required argument 'fd' (pos 1)

# %%
os.chdir("C:\\Users\\Shubham\\Documents\\")
os.getcwd()
# Out:
# 'C:\\Users\\Shubham\\Documents'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Data Science',
#  'DCA',
#  'desktop.ini',
#  'McAfee Vaults',
#  'My Music',
#  'My Pictures',
#  'My Videos',
#  'Python Developer',
#  'Soft Skills',
#  'YouTube.pdf']

# %% [markdown]
# # 2. Sys

# %%
import sys

# %%
sys.stderr.write('This is error')
# Out:
# This is error

# %%
sys.stderr.flush()

# %%
sys.argv[0]
# Out:
# 'C:\\Users\\Shubham\\anaconda3\\lib\\site-packages\\ipykernel_launcher.py'

# %%
os.rmdir("New Folder")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-45-c1b5102139b5> in <module>
# ----> 1 os.rmdir("New Folder")
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'New Folder'

# %%
s=os.getcwd()
os.mkdir("New Folder")
os.chdir(s+"\\New Folder")
os.getcwd()
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-51-1fe79b5025f7> in <module>
#       1 s=os.getcwd()
# ----> 2 os.mkdir("New Folder")
#       3 os.chdir(s+"\\New Folder")
#       4 os.getcwd()
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'New Folder'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Shubham\\Documents\\New Folder\\New Folder\\New Folder\\New Folder'

# %%
os.rmdir('New Folder')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-47-38ef03a7b4cf> in <module>
# ----> 1 os.rmdir('New Folder')
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'New Folder'

# %%
os.chdir("C:\\Users\\Shubham\\")

# %%
import os
#Write your code here
s = os.getcwd()
os.mkdir("New Folder")
os.chdir(s+"\\New Folder")
q = os.getcwd()

os.chdir(s)
os.rename("New Folder", "New Folder2")
os.chdir(s+"\\New Folder2")
p = os.getcwd()

os.chdir(s)
os.rmdir("New Folder2")
w = os.getcwd()

# %%
print(s)
print(q)
print(p)
print(w)
# Out:
# C:\Users\Shubham
# C:\Users\Shubham\New Folder
# C:\Users\Shubham\New Folder2
# C:\Users\Shubham

# %%
os.rmdir("New Folder")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-58-c1b5102139b5> in <module>
# ----> 1 os.rmdir("New Folder")
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'New Folder'
